# %% [markdown]
# <a href="https://colab.research.google.com/github/mahn-bonnie/Car-Purchase-Amount-Predictions-using-ML/blob/main/Car_Purchase_Amount_Predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # We are going to develop a machine learning model to predict the total dollar amount that customers are willing to pay while purchasing a car given the following attributes:
#
# # Customer Name
# # Customer e-mail
# # Country
# # Gender
# # Age
# # Annual Salary
# # Credit Card Debt
# # Net Worth
# # The model should predict:
#
# # Car Purchase Amount

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
data = pd.read_csv('Car_Purchasing_Data.csv')

# %% [markdown]
# # **Display Top 5 Rows of The Dataset**

# %%
data.head()
# Out:
#      Customer Name                                    Customer e-mail Country  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu     USA
# 1    Harlan Barnes                                eu.dolor@diam.co.uk     USA
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...     USA
# 3  Jade Cunningham                            malesuada@dignissim.com     USA
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net     USA
#
#    Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# 0       0   42    62812.09301      11609.380910  238961.2505
# 1       0   41    66646.89292       9572.957136  530973.9078
# 2       1   43    53798.55112      11160.355060  638467.1773
# 3       1   58    79370.03798      14426.164850  548599.0524
# 4       1   57    59729.15130       5358.712177  560304.0671
#
#    Car Purchase Amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %% [markdown]
# # **Display The Last 5 Rows of The Dataset**

# %%
data.tail()
# Out:
#     Customer Name                     Customer e-mail Country  Gender  Age  \
# 495        Walter                 ligula@Cumsociis.ca     USA       0   41
# 496         Vanna  Cum.sociis.natoque@Sedmolestie.edu     USA       1   38
# 497         Pearl       penatibus.et@massanonante.com     USA       1   54
# 498          Nell   Quisque.varius@arcuVivamussit.net     USA       1   59
# 499         Marla           Camaron.marla@hotmail.com     USA       1   47
#
#      Annual Salary  Credit Card Debt    Net Worth  Car Purchase Amount
# 495    71942.40291       6995.902524  541670.1016          48901.44342
# 496    56039.49793      12301.456790  360419.0988          31491.41457
# 497    68888.77805      10611.606860  764531.3203          64147.28888
# 498    49811.99062      14013.034510  337826.6382          45442.15353
# 499    61370.67766       9391.341628  462946.4924          45107.22566

# %% [markdown]
# # **Find Shape of Our Dataset (Number of Rows And Number of Columns)**

# %%
data.shape
# Out:
# (500, 9)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 500
# Number of Columns 9

# %% [markdown]
# # **Get Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Customer Name        500 non-null    object
#  1   Customer e-mail      500 non-null    object
#  2   Country              500 non-null    object
#  3   Gender               500 non-null    int64
#  4   Age                  500 non-null    int64
#  5   Annual Salary        500 non-null    float64
#  6   Credit Card Debt     500 non-null    float64
#  7   Net Worth            500 non-null    float64
#  8   Car Purchase Amount  500 non-null    float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 35.3+ KB

# %% [markdown]
# # **Check Null Values In The Dataset**

# %%
data.isnull().sum()
# Out:
# Customer Name          0
# Customer e-mail        0
# Country                0
# Gender                 0
# Age                    0
# Annual Salary          0
# Credit Card Debt       0
# Net Worth              0
# Car Purchase Amount    0
# dtype: int64

# %% [markdown]
# # **Get Overall Statistics About The Dataset**

# %%
data.describe()
# Out:
#            Gender         Age  Annual Salary  Credit Card Debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.224000   62127.239608       9607.645049
# std      0.500465    7.990339   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   41.000000   54391.977195       7397.515792
# 50%      1.000000   46.000000   62915.497035       9655.035568
# 75%      1.000000   52.000000   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             Net Worth  Car Purchase Amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %% [markdown]
# # **Visualization**

# %%
import seaborn as sns

# %%
sns.pairplot(data)

# %% [markdown]
# # **Store Feature Matrix In X and Response(Target) In Vector y**

# %%
data.columns
# Out:
# Index(['Customer Name', 'Customer e-mail', 'Country', 'Gender', 'Age',
#        'Annual Salary', 'Credit Card Debt', 'Net Worth',
#        'Car Purchase Amount'],
#       dtype='object')

# %%
X = data.drop(['Customer Name','Customer e-mail','Country','Car Purchase Amount'],axis=1)

# %%
y = data['Car Purchase Amount']

# %%
y
# Out:
# 0      35321.45877
# 1      45115.52566
# 2      42925.70921
# 3      67422.36313
# 4      55915.46248
#           ...
# 495    48901.44342
# 496    31491.41457
# 497    64147.28888
# 498    45442.15353
# 499    45107.22566
# Name: Car Purchase Amount, Length: 500, dtype: float64

# %% [markdown]
# # **Feature Scaling(Normalization)**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler()
X_scaled = sc.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.        , 0.44      , 0.53515116, 0.57836085, 0.22342985],
#        [0.        , 0.42      , 0.58308616, 0.476028  , 0.52140195],
#        [1.        , 0.46      , 0.42248189, 0.55579674, 0.63108896],
#        ...,
#        [1.        , 0.68      , 0.61110973, 0.52822145, 0.75972584],
#        [1.        , 0.78      , 0.37264988, 0.69914746, 0.3243129 ],
#        [1.        , 0.54      , 0.51713347, 0.46690159, 0.45198622]])

# %%
sc1 = MinMaxScaler()
y_reshape= y.values.reshape(-1,1)
y_scaled = sc1.fit_transform(y_reshape)
y_scaled
# Out:
# array([[0.37072477],
#        [0.50866938],
#        [0.47782689],
#        [0.82285018],
#        [0.66078116],
#        [0.67059152],
#        [0.28064374],
#        [0.54133778],
#        [0.54948752],
#        [0.4111198 ],
#        [0.70486638],
#        [0.46885649],
#        [0.27746526],
#        [0.56702642],
#        [0.57056385],
#        [0.61996151],
#        [0.46217916],
#        [0.49157341],
#        [0.50188722],
#        [0.64545808],
#        [0.59339372],
#        [0.48453965],
#        [0.53860366],
#        [0.53007738],
#        [0.50814651],
#        [0.49841668],
#        [0.3966416 ],
#        [0.56467566],
#        [0.6950749 ],
#        [0.49287831],
#        [0.12090943],
#        [0.50211776],
#        [0.80794216],
#        [0.62661214],
#        [0.43394857],
#        [0.60017103],
#        [0.42223485],
#        [0.01538345],
#        [0.37927499],
#        [0.64539707],
#        [0.51838974],
#        [0.45869677],
#        [0.26804521],
#        [0.2650104 ],
#        [0.84054134],
#        [0.84401542],
#        [0.35515157],
#        [0.406246  ],
#        [0.40680623],
#        [0.55963883],
#        [0.2561583 ],
#        [0.77096325],
#        [0.55305289],
#        [0.5264948 ],
#        [0.3236476 ],
#        [0.55070832],
#        [0.54057623],
#        [0.45669016],
#        [0.41053254],
#        [0.33433524],
#        [0.39926954],
#        [0.5420261 ],
#        [0.57366948],
#        [0.43793831],
#        [0.46897896],
#        [0.61908354],
#        [0.55076214],
#        [0.48846357],
#        [0.61560519],
#        [0.56891394],
#        [0.30761974],
#        [0.56863909],
#        [0.46343171],
#        [0.50787179],
#        [0.61959897],
#        [0.59095889],
#        [0.45573492],
#        [0.49908055],
#        [0.4155271 ],
#        [0.45382041],
#        [0.76253593],
#        [0.30644588],
#        [0.79707352],
#        [0.40664378],
#        [0.47773971],
#        [0.19154167],
#        [0.86759109],
#        [0.48228989],
#        [0.41040247],
#        [0.30168732],
#        [0.77280198],
#        [0.50863303],
#        [0.49805458],
#        [0.14824364],
#        [0.57734658],
#        [0.7427002 ],
#        [0.4615406 ],
#        [0.52679628],
#        [0.39967091],
#        [0.34882593],
#        [0.3051776 ],
#        [0.60642838],
#        [0.30614901],
#        [0.4287247 ],
#        [0.41091372],
#        [0.44492764],
#        [0.74688327],
#        [0.5558489 ],
#        [0.43795845],
#        [0.571387  ],
#        [0.31561446],
#        [0.54534475],
#        [0.37724541],
#        [0.47754279],
#        [0.55657526],
#        [0.51540401],
#        [0.32481193],
#        [0.32687852],
#        [0.37288737],
#        [0.28900791],
#        [0.6538108 ],
#        [0.46675557],
#        [0.58506904],
#        [0.36510463],
#        [0.49152498],
#        [0.42443705],
#        [0.45278122],
#        [0.21316327],
#        [0.4747199 ],
#        [0.42114943],
#        [0.27669569],
#        [0.60775236],
#        [0.81194719],
#        [0.47759537],
#        [0.56687473],
#        [0.25779114],
#        [0.54746234],
#        [0.71808681],
#        [0.51086565],
#        [0.        ],
#        [0.52129727],
#        [0.33756622],
#        [0.56035434],
#        [0.51865585],
#        [0.43805795],
#        [0.3726359 ],
#        [0.2895323 ],
#        [0.41187412],
#        [0.499023  ],
#        [0.59220313],
#        [0.61366712],
#        [0.73808769],
#        [0.27413582],
#        [0.26177748],
#        [0.54900684],
#        [0.26992761],
#        [0.85449963],
#        [0.55003734],
#        [0.39949626],
#        [0.50001154],
#        [0.36815842],
#        [0.6502447 ],
#        [0.55469987],
#        [0.37779655],
#        [0.38757338],
#        [0.62128001],
#        [0.62041473],
#        [0.17564949],
#        [0.50726309],
#        [0.65320953],
#        [0.6691568 ],
#        [0.54146119],
#        [0.45760058],
#        [0.33173992],
#        [0.46457217],
#        [0.7118085 ],
#        [0.4556686 ],
#        [0.61669253],
#        [0.71996731],
#        [0.54592485],
#        [0.77729956],
#        [0.56199216],
#        [0.31678049],
#        [0.77672238],
#        [0.51326977],
#        [0.50855247]])

# %% [markdown]
# # **Splitting the Dataset into Training Set and Test Set**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y_scaled,test_size=0.20,random_state=42)

# %% [markdown]
# # **Import The Models**

# %%
data.head()
# Out:
#      Customer Name                                    Customer e-mail Country  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu     USA
# 1    Harlan Barnes                                eu.dolor@diam.co.uk     USA
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...     USA
# 3  Jade Cunningham                            malesuada@dignissim.com     USA
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net     USA
#
#    Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# 0       0   42    62812.09301      11609.380910  238961.2505
# 1       0   41    66646.89292       9572.957136  530973.9078
# 2       1   43    53798.55112      11160.355060  638467.1773
# 3       1   58    79370.03798      14426.164850  548599.0524
# 4       1   57    59729.15130       5358.712177  560304.0671
#
#    Car Purchase Amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %% [markdown]
# # **Model Training**

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)

svm = SVR()
svm.fit(X_train,y_train)

rf = RandomForestRegressor()
rf.fit(X_train,y_train)


gbr = GradientBoostingRegressor()
gbr.fit(X_train,y_train)

xg = XGBRegressor()
xg.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# # **Building The ANN**

# %%
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# # **Initialize The ANN**

# %%
ann = Sequential()

# %% [markdown]
# # **Adding input layer and first hidden layer**

# %%
ann.add(Dense(25,input_dim=5,activation='relu'))

# %% [markdown]
# # **Adding Second hidden layer**

# %%
ann.add(Dense(25,activation='relu'))

# %% [markdown]
# # **Adding the output layer**

# %%
ann.add(Dense(1,activation='linear'))

# %% [markdown]
# # **Training The ANN**

# %%
ann.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 25)                150
#
#  dense_1 (Dense)             (None, 25)                650
#
#  dense_2 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 826 (3.23 KB)
# Trainable params: 826 (3.23 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
ann.compile(optimizer='adam',loss='mean_squared_error')

# %%
ann.fit(X_train,y_train,epochs=100,batch_size=50,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 3s 67ms/step - loss: 0.1457 - val_loss: 0.0689
# Epoch 2/100
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0740 - val_loss: 0.0273
# Epoch 3/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0331 - val_loss: 0.0125
# Epoch 4/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0166 - val_loss: 0.0110
# Epoch 5/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0134 - val_loss: 0.0127
# Epoch 6/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0128 - val_loss: 0.0113
# Epoch 7/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0111 - val_loss: 0.0084
# Epoch 8/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0097 - val_loss: 0.0065
# Epoch 9/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0090 - val_loss: 0.0059
# Epoch 10/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0084 - val_loss: 0.0056
# Epoch 11/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0079 - val_loss: 0.0054
# Epoch 12/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0073 - val_loss: 0.0051
# Epoch 13/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0070 - val_loss: 0.0049
# Epoch 14/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0066 - val_loss: 0.0046
# Epoch 15/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0063 - val_loss: 0.0045
# Epoch 16/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0060 - val_loss: 0.0043
# Epoch 17/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0057 - val_loss: 0.0040
# Epoch 18/100
# 7/7 [==============================] - 0s 12ms/step - loss: 0.0054 - val_loss: 0.0038
# Epoch 19/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0051 - val_loss: 0.0037
# Epoch 20/100
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0035
# Epoch 21/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0046 - val_loss: 0.0032
# Epoch 22/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0044 - val_loss: 0.0031
# Epoch 23/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 24/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0039 - val_loss: 0.0028
# Epoch 25/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0037 - val_loss: 0.0026
# Epoch 26/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 27/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0023
# Epoch 28/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0022
# Epoch 29/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 30/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 31/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0026 - val_loss: 0.0018
# Epoch 32/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 33/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 34/100
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 35/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0014
# Epoch 36/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 37/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 38/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 39/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.0011
# Epoch 40/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 41/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 9.9893e-04
# Epoch 42/100
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 9.3810e-04
# Epoch 43/100
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0012 - val_loss: 8.8081e-04
# Epoch 44/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 8.3585e-04
# Epoch 45/100
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 7.7868e-04
# Epoch 46/100
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 7.6020e-04
# Epoch 47/100
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 7.4647e-04
# Epoch 48/100
# 7/7 [==============================] - 0s 8ms/step - loss: 9.9243e-04 - val_loss: 7.1682e-04
# Epoch 49/100
# 7/7 [==============================] - 0s 12ms/step - loss: 9.5384e-04 - val_loss: 6.9101e-04
# Epoch 50/100
# 7/7 [==============================] - 0s 9ms/step - loss: 9.2010e-04 - val_loss: 6.5743e-04
# Epoch 51/100
# 7/7 [==============================] - 0s 8ms/step - loss: 8.7539e-04 - val_loss: 6.4424e-04
# Epoch 52/100
# 7/7 [==============================] - 0s 8ms/step - loss: 8.5063e-04 - val_loss: 6.3545e-04
# Epoch 53/100
# 7/7 [==============================] - 0s 8ms/step - loss: 8.0538e-04 - val_loss: 6.1748e-04
# Epoch 54/100
# 7/7 [==============================] - 0s 8ms/step - loss: 7.7730e-04 - val_loss: 5.6918e-04
# Epoch 55/100
# 7/7 [==============================] - 0s 8ms/step - loss: 7.3463e-04 - val_loss: 5.4573e-04
# Epoch 56/100
# 7/7 [==============================] - 0s 10ms/step - loss: 6.9946e-04 - val_loss: 5.2286e-04
# Epoch 57/100
# 7/7 [==============================] - 0s 8ms/step - loss: 6.5966e-04 - val_loss: 4.9478e-04
# Epoch 58/100
# 7/7 [==============================] - 0s 8ms/step - loss: 6.1172e-04 - val_loss: 4.6141e-04
# Epoch 59/100
# 7/7 [==============================] - 0s 8ms/step - loss: 5.6790e-04 - val_loss: 4.2651e-04
# Epoch 60/100
# 7/7 [==============================] - 0s 11ms/step - loss: 5.2879e-04 - val_loss: 4.1926e-04
# Epoch 61/100
# 7/7 [==============================] - 0s 11ms/step - loss: 4.9950e-04 - val_loss: 3.9791e-04
# Epoch 62/100
# 7/7 [==============================] - 0s 11ms/step - loss: 4.6821e-04 - val_loss: 3.8281e-04
# Epoch 63/100
# 7/7 [==============================] - 0s 8ms/step - loss: 4.4328e-04 - val_loss: 3.6510e-04
# Epoch 64/100
# 7/7 [==============================] - 0s 9ms/step - loss: 4.2312e-04 - val_loss: 3.6359e-04
# Epoch 65/100
# 7/7 [==============================] - 0s 10ms/step - loss: 4.0014e-04 - val_loss: 3.5827e-04
# Epoch 66/100
# 7/7 [==============================] - 0s 11ms/step - loss: 3.8451e-04 - val_loss: 3.4013e-04
# Epoch 67/100
# 7/7 [==============================] - 0s 12ms/step - loss: 3.6535e-04 - val_loss: 3.3679e-04
# Epoch 68/100
# 7/7 [==============================] - 0s 9ms/step - loss: 3.3879e-04 - val_loss: 3.4351e-04
# Epoch 69/100
# 7/7 [==============================] - 0s 11ms/step - loss: 3.1943e-04 - val_loss: 3.1337e-04
# Epoch 70/100
# 7/7 [==============================] - 0s 11ms/step - loss: 3.0259e-04 - val_loss: 2.9113e-04
# Epoch 71/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.9020e-04 - val_loss: 2.7668e-04
# Epoch 72/100
# 7/7 [==============================] - 0s 8ms/step - loss: 2.6979e-04 - val_loss: 2.7189e-04
# Epoch 73/100
# 7/7 [==============================] - 0s 12ms/step - loss: 2.6569e-04 - val_loss: 2.5214e-04
# Epoch 74/100
# 7/7 [==============================] - 0s 7ms/step - loss: 2.3609e-04 - val_loss: 2.3671e-04
# Epoch 75/100
# 7/7 [==============================] - 0s 10ms/step - loss: 2.1787e-04 - val_loss: 2.1908e-04
# Epoch 76/100
# 7/7 [==============================] - 0s 9ms/step - loss: 2.0166e-04 - val_loss: 2.0862e-04
# Epoch 77/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.8320e-04 - val_loss: 1.9329e-04
# Epoch 78/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.7090e-04 - val_loss: 1.8785e-04
# Epoch 79/100
# 7/7 [==============================] - 0s 13ms/step - loss: 1.5924e-04 - val_loss: 1.7416e-04
# Epoch 80/100
# 7/7 [==============================] - 0s 9ms/step - loss: 1.4622e-04 - val_loss: 1.6961e-04
# Epoch 81/100
# 7/7 [==============================] - 0s 8ms/step - loss: 1.3956e-04 - val_loss: 1.5235e-04
# Epoch 82/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.3094e-04 - val_loss: 1.5587e-04
# Epoch 83/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.2807e-04 - val_loss: 1.3418e-04
# Epoch 84/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.1644e-04 - val_loss: 1.2309e-04
# Epoch 85/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.1298e-04 - val_loss: 1.2041e-04
# Epoch 86/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0633e-04 - val_loss: 1.0797e-04
# Epoch 87/100
# 7/7 [==============================] - 0s 8ms/step - loss: 9.9597e-05 - val_loss: 1.0548e-04
# Epoch 88/100
# 7/7 [==============================] - 0s 11ms/step - loss: 9.4426e-05 - val_loss: 1.0014e-04
# Epoch 89/100
# 7/7 [==============================] - 0s 12ms/step - loss: 8.9580e-05 - val_loss: 9.8072e-05
# Epoch 90/100
# 7/7 [==============================] - 0s 12ms/step - loss: 8.7651e-05 - val_loss: 1.0006e-04
# Epoch 91/100
# 7/7 [==============================] - 0s 8ms/step - loss: 8.5713e-05 - val_loss: 9.1551e-05
# Epoch 92/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.9954e-05 - val_loss: 9.0013e-05
# Epoch 93/100
# 7/7 [==============================] - 0s 14ms/step - loss: 7.7617e-05 - val_loss: 8.9270e-05
# Epoch 94/100
# 7/7 [==============================] - 0s 8ms/step - loss: 7.6382e-05 - val_loss: 9.1212e-05
# Epoch 95/100
# 7/7 [==============================] - 0s 12ms/step - loss: 7.4265e-05 - val_loss: 8.5447e-05
# Epoch 96/100
# 7/7 [==============================] - 0s 11ms/step - loss: 7.3381e-05 - val_loss: 8.5946e-05
# Epoch 97/100
# 7/7 [==============================] - 0s 10ms/step - loss: 7.2688e-05 - val_loss: 9.0442e-05
# Epoch 98/100
# 7/7 [==============================] - 0s 10ms/step - loss: 7.1732e-05 - val_loss: 8.0125e-05
# Epoch 99/100
# 7/7 [==============================] - 0s 8ms/step - loss: 7.0358e-05 - val_loss: 9.0657e-05
# Epoch 100/100
# 7/7 [==============================] - 0s 8ms/step - loss: 7.2131e-05 - val_loss: 8.0443e-05

# %% [markdown]
# # **Prediction on Test Data**

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = svm.predict(X_test)
y_pred3 = rf.predict(X_test)
y_pred4 = gbr.predict(X_test)
y_pred5 = xg.predict(X_test)
y_pred6 = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %% [markdown]
# # **Evaluating The Algorithm**

# %%
from sklearn import metrics

# %%
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)
score5 = metrics.r2_score(y_test,y_pred5)
score6 = metrics.r2_score(y_test,y_pred6)

# %%
print(score1,score2,score3,score4,score5,score6)
# Out:
# 0.9994234310992762 0.9547066777872097 0.9556108962334405 0.9743944535031155 0.9505777322717386 0.9961958515383339

# %%
final_data = pd.DataFrame({'Models':['LR','SVR','RF','GBR','XG','ANN'],
              'R2_SCORE':[score1,score2,score3,score4,score5,score6]})

# %%
final_data
# Out:
#   Models  R2_SCORE
# 0     LR  0.999423
# 1    SVR  0.954707
# 2     RF  0.955611
# 3    GBR  0.974394
# 4     XG  0.950578
# 5    ANN  0.996196

# %%
import seaborn as sns

# %%
sns.barplot(x=final_data['Models'],y=final_data['R2_SCORE'])
# Out:
# <Axes: xlabel='Models', ylabel='R2_SCORE'>

# %% [markdown]
# # **Save The Model**

# %%
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense

# %%
ann = Sequential()

# %%
ann.add(Dense(25,input_dim=5,activation='relu'))
ann.add(Dense(25,activation='relu'))
ann.add(Dense(1,activation='linear'))
ann.compile(optimizer='adam',loss='mean_squared_error')

# %%
ann.fit(X_scaled,y_scaled,epochs=100,batch_size=50,verbose=1)
# Out:
# Epoch 1/100
# 10/10 [==============================] - 1s 5ms/step - loss: 0.2335
# Epoch 2/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1298
# Epoch 3/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0517
# Epoch 4/100
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0238
# Epoch 5/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0227
# Epoch 6/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0176
# Epoch 7/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0147
# Epoch 8/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0121
# Epoch 9/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0097
# Epoch 10/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0080
# Epoch 11/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0068
# Epoch 12/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0058
# Epoch 13/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0050
# Epoch 14/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0044
# Epoch 15/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0038
# Epoch 16/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0034
# Epoch 17/100
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0029
# Epoch 18/100
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0025
# Epoch 19/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0022
# Epoch 20/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0020
# Epoch 21/100
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0018
# Epoch 22/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0016
# Epoch 23/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0015
# Epoch 24/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 25/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0012
# Epoch 26/100
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0011
# Epoch 27/100
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0010
# Epoch 28/100
# 10/10 [==============================] - 0s 6ms/step - loss: 9.3204e-04
# Epoch 29/100
# 10/10 [==============================] - 0s 5ms/step - loss: 8.5941e-04
# Epoch 30/100
# 10/10 [==============================] - 0s 5ms/step - loss: 8.1556e-04
# Epoch 31/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.4907e-04
# Epoch 32/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.8399e-04
# Epoch 33/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.3374e-04
# Epoch 34/100
# 10/10 [==============================] - 0s 5ms/step - loss: 5.9636e-04
# Epoch 35/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.5235e-04
# Epoch 36/100
# 10/10 [==============================] - 0s 4ms/step - loss: 5.1421e-04
# Epoch 37/100
# 10/10 [==============================] - 0s 4ms/step - loss: 4.6329e-04
# Epoch 38/100
# 10/10 [==============================] - 0s 5ms/step - loss: 4.2938e-04
# Epoch 39/100
# 10/10 [==============================] - 0s 5ms/step - loss: 4.0261e-04
# Epoch 40/100
# 10/10 [==============================] - 0s 8ms/step - loss: 3.6232e-04
# Epoch 41/100
# 10/10 [==============================] - 0s 5ms/step - loss: 3.4459e-04
# Epoch 42/100
# 10/10 [==============================] - 0s 5ms/step - loss: 3.0773e-04
# Epoch 43/100
# 10/10 [==============================] - 0s 9ms/step - loss: 2.8571e-04
# Epoch 44/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.7075e-04
# Epoch 45/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5619e-04
# Epoch 46/100
# 10/10 [==============================] - 0s 5ms/step - loss: 2.4310e-04
# Epoch 47/100
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2157e-04
# Epoch 48/100
# 10/10 [==============================] - 0s 8ms/step - loss: 2.0427e-04
# Epoch 49/100
# 10/10 [==============================] - 0s 5ms/step - loss: 2.0034e-04
# Epoch 50/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8527e-04
# Epoch 51/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7544e-04
# Epoch 52/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6433e-04
# Epoch 53/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6144e-04
# Epoch 54/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.5853e-04
# Epoch 55/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5241e-04
# Epoch 56/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5005e-04
# Epoch 57/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.4863e-04
# Epoch 58/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.3978e-04
# Epoch 59/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.3005e-04
# Epoch 60/100
# 10/10 [==============================] - 0s 7ms/step - loss: 1.2813e-04
# Epoch 61/100
# 10/10 [==============================] - 0s 8ms/step - loss: 1.2638e-04
# Epoch 62/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2853e-04
# Epoch 63/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2480e-04
# Epoch 64/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1598e-04
# Epoch 65/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1536e-04
# Epoch 66/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.1490e-04
# Epoch 67/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.1121e-04
# Epoch 68/100
# 10/10 [==============================] - 0s 5ms/step - loss: 1.0828e-04
# Epoch 69/100
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0444e-04
# Epoch 70/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0020e-04
# Epoch 71/100
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0170e-04
# Epoch 72/100
# 10/10 [==============================] - 0s 3ms/step - loss: 9.6412e-05
# Epoch 73/100
# 10/10 [==============================] - 0s 3ms/step - loss: 9.8924e-05
# Epoch 74/100
# 10/10 [==============================] - 0s 3ms/step - loss: 9.5174e-05
# Epoch 75/100
# 10/10 [==============================] - 0s 3ms/step - loss: 9.2778e-05
# Epoch 76/100
# 10/10 [==============================] - 0s 3ms/step - loss: 9.0919e-05
# Epoch 77/100
# 10/10 [==============================] - 0s 3ms/step - loss: 9.2907e-05
# Epoch 78/100
# 10/10 [==============================] - 0s 4ms/step - loss: 9.3281e-05
# Epoch 79/100
# 10/10 [==============================] - 0s 4ms/step - loss: 9.0381e-05
# Epoch 80/100
# 10/10 [==============================] - 0s 3ms/step - loss: 9.0818e-05
# Epoch 81/100
# 10/10 [==============================] - 0s 4ms/step - loss: 8.5218e-05
# Epoch 82/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.5390e-05
# Epoch 83/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.5328e-05
# Epoch 84/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.9240e-05
# Epoch 85/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.1999e-05
# Epoch 86/100
# 10/10 [==============================] - 0s 4ms/step - loss: 7.7338e-05
# Epoch 87/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.5398e-05
# Epoch 88/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.6456e-05
# Epoch 89/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.9279e-05
# Epoch 90/100
# 10/10 [==============================] - 0s 3ms/step - loss: 8.1359e-05
# Epoch 91/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.2832e-05
# Epoch 92/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.0770e-05
# Epoch 93/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.3541e-05
# Epoch 94/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.6905e-05
# Epoch 95/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.4474e-05
# Epoch 96/100
# 10/10 [==============================] - 0s 3ms/step - loss: 7.0624e-05
# Epoch 97/100
# 10/10 [==============================] - 0s 3ms/step - loss: 6.6759e-05
# Epoch 98/100
# 10/10 [==============================] - 0s 3ms/step - loss: 6.7005e-05
# Epoch 99/100
# 10/10 [==============================] - 0s 5ms/step - loss: 6.7240e-05
# Epoch 100/100
# 10/10 [==============================] - 0s 3ms/step - loss: 6.3761e-05

# %%
import joblib

# %%
joblib.dump(ann,'car_model')
# Out:
# ['car_model']

# %%
model = joblib.load('car_model')

# %% [markdown]
# # **Prediction on New Data**

# %%
import numpy as np

# %%
data.head(1)
# Out:
#    Customer Name                                    Customer e-mail Country  \
# 0  Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu     USA
#
#    Gender  Age  Annual Salary  Credit Card Debt    Net Worth  \
# 0       0   42    62812.09301       11609.38091  238961.2505
#
#    Car Purchase Amount
# 0          35321.45877

# %%
X_test1=sc.transform(np.array([[0,42,62812.09301,11609.38091,238961.2505]]))

# %%
X_test1
# Out:
# array([[0.        , 0.44      , 0.53515116, 0.57836085, 0.22342985]])

# %%
pred = ann.predict(X_test1)
# Out:
# 1/1 [==============================] - 0s 111ms/step

# %%
sc1.inverse_transform(pred)
# Out:
# array([[35470.707]], dtype=float32)

# %%
35321.45877
# Out:
# 35321.45877

# %% [markdown]
# # **GUI**

# %%
import numpy as np
from tkinter import *
from sklearn.preprocessing import StandardScaler
import joblib

# %%
def show_entry_fields():
    p1=float(e1.get())
    p2=float(e2.get())
    p3=float(e3.get())
    p4=float(e4.get())
    p5=float(e5.get())

    model = joblib.load('car_model')
    result=model.predict(sc.transform(np.array([[p1,p2,p3,p4,p5]])))
    Label(master, text="Car Purchase amount").grid(row=8)
    Label(master, text=sc1.inverse_transform(result)).grid(row=10)
    print("Car Purchase amount", sc1.inverse_transform(result)[0][0])

master = Tk()
master.title("Car Purchase Amount Predictions Using Machine Learning")


label = Label(master, text = "Car Purchase Amount Predictions Using ML"
                          , bg = "black", fg = "white"). \
                               grid(row=0,columnspan=2)


Label(master, text="Gender").grid(row=1)
Label(master, text="Age").grid(row=2)
Label(master, text="Annual Salary").grid(row=3)
Label(master, text="Credit Card Debt").grid(row=4)
Label(master, text="Net Worth").grid(row=5)


e1 = Entry(master)
e2 = Entry(master)
e3 = Entry(master)
e4 = Entry(master)
e5 = Entry(master)

e1.grid(row=1, column=1)
e2.grid(row=2, column=1)
e3.grid(row=3, column=1)
e4.grid(row=4, column=1)
e5.grid(row=5, column=1)


Button(master, text='Predict', command=show_entry_fields).grid()

mainloop()

# %% [markdown]
# # **ANN Visualizer**

# %%
# !pip3 install ann_visualizer
# !pip install graphviz
import ann_visualizer
# Out:
# Requirement already satisfied: ann_visualizer in /usr/local/lib/python3.10/dist-packages (2.5)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.1)

# %%
from ann_visualizer.visualize import ann_viz;

# %%
ann_viz(ann, title="ANN", view=True)
